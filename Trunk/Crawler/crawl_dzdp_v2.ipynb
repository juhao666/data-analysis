# %%
import urllib
from bs4 import BeautifulSoup
import xlwt
import json
import re


def parse(url):
    #body
    headers={'Accept': 'application/json, text/javascript', 
         'User-Agent':'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36',
         'cookie': 's_ViewType=10; _lxsdk_cuid=1714a6f6dc576-0351aabd617323-5463377a-a41c3-1714a6f6dc6c8; _lxsdk=1714a6f6dc576-0351aabd617323-5463377a-a41c3-1714a6f6dc6c8; _hc.v=9b3f5fce-2b77-d20f-1b3b-ebf7c793f66e.1586091755; wed_user_path=2786|0; aburl=1; cy=17; cye=xian; dplet=4a206248cf9cd97ea5b23332ab9c74c6; dper=017c7cde4689ccbe3b4e92a96c6e578e4d48e3d871c987831fb9f5436f0c11b16b545df35a4c190b74969ae455872e22b081eb71864dd6ce179556929ab51251f1f2a3a60191e17c2887ae86e185543122365cdcd5dc61d0347d49212cc710c4; ll=7fd06e815b796be3df069dec7836c3df; ua=%E7%82%AC%E7%81%8F; ctu=51082c643abca2e4a4729d35da419781a5baa93bd770d869eb48bf863a23f42c; _lxsdk_s=1714a6f6dc7-af0-f8f-b5a%7C%7C232'}

    req=urllib.request.Request(url,headers=headers)
    
    response = urllib.request.urlopen(req)
    html=response.read().decode('utf-8')
    
 
    soup = BeautifulSoup(html,'html.parser')
    all_item_divs = soup.find_all(class_='txt')
    #print(all_item_divs )
    if all_item_divs:
        for item in all_item_divs:
            all_topics = item.find_all('a')
       
            for topic in all_topics:
                click = topic['data-click-name']
                title=''
                href=''
                phone =''
                like =''
                price ='' 
                if click == "shop_title_click":
                    title = topic['title']
                    href = topic['href'].strip()
                    #print('{0} {1}'.format(title,href))
                    #headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.1; rv:67.0) Gecko/20100101 Firefox/67.0'}
                    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36',
         'cookie': 's_ViewType=10; _lxsdk_cuid=1714a6f6dc576-0351aabd617323-5463377a-a41c3-1714a6f6dc6c8; _lxsdk=1714a6f6dc576-0351aabd617323-5463377a-a41c3-1714a6f6dc6c8; _hc.v=9b3f5fce-2b77-d20f-1b3b-ebf7c793f66e.1586091755; wed_user_path=2786|0; aburl=1; cy=17; cye=xian; dplet=4a206248cf9cd97ea5b23332ab9c74c6; dper=017c7cde4689ccbe3b4e92a96c6e578e4d48e3d871c987831fb9f5436f0c11b16b545df35a4c190b74969ae455872e22b081eb71864dd6ce179556929ab51251f1f2a3a60191e17c2887ae86e185543122365cdcd5dc61d0347d49212cc710c4; ll=7fd06e815b796be3df069dec7836c3df; ua=%E7%82%AC%E7%81%8F; ctu=51082c643abca2e4a4729d35da419781a5baa93bd770d869eb48bf863a23f42c; _lxsdk_s=1714a6f6dc7-af0-f8f-b5a%7C%7C232'}

                    req_shop=urllib.request.Request(href,headers=headers)
                    resp_shop = urllib.request.urlopen(req_shop)
                    html_shop=resp_shop.read().decode('utf-8')
                    soup_shop = BeautifulSoup(html_shop ,'html.parser')
                    like_price = soup_shop.find_all(class_='rst-taste')
                    shop_info = soup_shop.find_all(class_='shopinfor')     
                    #print(shop_info)                         
                    if shop_info:
                        phone = shop_info[0].find_all('p')[0].get_text()
                        #print(phone)
                        if like_price:
                            like = like_price[0].find_all('a')[0].get_text()
                            #print(like)
                            price = like_price[0].find_all('strong')[0].get_text()
                            #print(price)
                    else:                                         
                        like_price = soup_shop.find_all(class_='comment-rst')
                        shop_infos = soup_shop.find_all(class_='shop-info-content')
                        if like_price:
                            if like_price[0].find('a'):
                                like = like_price[0].find('a').get_text()
                            #print(like)
                            if like_price[0].find('dd'):
                                price = like_price[0].find('dd').get_text()
                            #print(price)
                        for shop_info in shop_infos:
                            #print(shop_info)
                            for x in shop_info.find_all('a'):
                                #print(x)
                                if x.has_attr('data-real'):
                                    phone = x['data-real']
                                    #print(phone)
                    print('{0}\t{1}\t{2}\t{3}\t{4}\t'.format(title,href,like,price,phone))

url = "http://www.dianping.com/search/keyword/17/0_%E6%9C%88%E5%AD%90%E4%BC%9A%E6%89%80/o3p"
for n in range(1,10):
    url = url+str(n)
    parse(url)

print('running over')
# Out:
# 好孕妈妈月嫂育儿嫂(旺座国际总店)	http://www.dianping.com/shop/127148438	339封点评	￥10711	商家客服：4001764171
#
# 金贝儿月嫂(大差市店)	http://www.dianping.com/shop/1252546534
# 133封点评
#             	¥10703	18502988629
# MIND 普拉提	http://www.dianping.com/shop/1353281886
# 安心妈妈月子中心(北郊店)	http://www.dianping.com/shop/75253324
# 499封点评
#             	¥28432	4000055810
# 曲江妇产医院	http://www.dianping.com/shop/4674300
# 悦长安母婴专护中心(凤城八路店)	http://www.dianping.com/shop/103004999	216封点评	￥26233	商家客服：029-86683868  17392835963
#
# 芒果妈咪月嫂服务中心(未央总店)	http://www.dianping.com/shop/120003421	106封点评	￥9484	商家客服：4001760442
#
# 金贝儿月嫂(交大店)	http://www.dianping.com/shop/132802110
# 99封点评
#             	¥11067	18502988627
# 爱菲月子会所(长安店)	http://www.dianping.com/shop/128027816	156封点评	￥19725	商家客服：13991954900  029-85950575
#
# 胜蓝月子会所(立丰国际店)	http://www.dianping.com/shop/23294982
# 371封点评
#             	¥22368	029--82284440
# 金贝儿月嫂(高新店)	http://www.dianping.com/shop/131450104
# 93封点评
#             	¥10540	029--89106537
# 品悦宫月子中心	http://www.dianping.com/shop/76717479	313封点评	￥23550	商家客服：4001769335
#
# 爱菲月子中心(太白店)	http://www.dianping.com/shop/67069768
# 440封点评
#             	¥21235	029--62890055
# 昕悦里母婴精致护理中心	http://www.dianping.com/shop/122270210
# 177封点评
#             	¥23021	18792701756
# 禧贝阁母婴呵护中心(市图书馆店)	http://www.dianping.com/shop/126243413	119封点评	￥29241	商家客服：4000303096-97270
#
# 玥姮心智家政母婴培训学校	http://www.dianping.com/shop/20809853
# 三彩家政月嫂育儿嫂中心(金辉世界城店)	http://www.dianping.com/shop/1207682395
# 2封点评
#             	-	15319726210
# 三彩家政母婴公司(西影路分店)	http://www.dianping.com/shop/556125999
#                 暂无点评
#             	-
# 品月阁母婴会所	http://www.dianping.com/shop/90056777
# 18封点评
#             	-	029--83668891
# 女王假日月子会所	http://www.dianping.com/shop/93947252
# 4封点评
#             	-	029--82282202
# 梦缘天使月子会所月嫂家政	http://www.dianping.com/shop/101941499
# 26封点评
#             	¥16633	13509185072
# 美睦月子会所	http://www.dianping.com/shop/110309765
# 19封点评
#             	¥20687	13572001381
# 菲比月子会所	http://www.dianping.com/shop/9030880
# 62封点评
#             	¥20221	029--89151515
# 美嘉好孕赴美生子月子中心(世纪金花店)	http://www.dianping.com/shop/110304246
# 3封点评
#             	-	029--61878009
# 爱宝专业催乳	http://www.dianping.com/shop/129942072
# 1封点评
#             	-	13259419868
# 奇妙宝贝母婴健康中心	http://www.dianping.com/shop/630463823
# 2封点评
#             	-	18066880615
# 拾月至喜月子会所	http://www.dianping.com/shop/111802466
# 15封点评
#             	¥17638	029--62355355
# 爱可多母婴护理中心	http://www.dianping.com/shop/1027998420	2封点评	-	商家客服：029-89531818  029-89532828
#
# 金月汇月子会所(铁通总店)	http://www.dianping.com/shop/5406613	36封点评	￥19741	商家客服：4001760418
#
# 金月汇月子会所(吉祥店)	http://www.dianping.com/shop/897979946
# 2封点评
#             	-	029--85216063
# running over

# %%
import urllib
from bs4 import BeautifulSoup
import xlwt
import json
import re

xls = xlwt.Workbook()
sheet = xls.add_sheet('ctx')
sheet.write(0,0,'title')
sheet.write(0,1,'url')
sheet.write(0,2,'like')
sheet.write(0,3,'price')
sheet.write(0,4,'phone')

url_b = "http://www.dianping.com/search/keyword/17/0_%E6%9C%88%E5%AD%90%E4%BC%9A%E6%89%80/o3p"
headers={'Accept': 'application/json, text/javascript', 
         'User-Agent':'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36',
         'cookie': 's_ViewType=10; _lxsdk_cuid=1714a6f6dc576-0351aabd617323-5463377a-a41c3-1714a6f6dc6c8; _lxsdk=1714a6f6dc576-0351aabd617323-5463377a-a41c3-1714a6f6dc6c8; _hc.v=9b3f5fce-2b77-d20f-1b3b-ebf7c793f66e.1586091755; wed_user_path=2786|0; aburl=1; cy=17; cye=xian; dplet=4a206248cf9cd97ea5b23332ab9c74c6; dper=017c7cde4689ccbe3b4e92a96c6e578e4d48e3d871c987831fb9f5436f0c11b16b545df35a4c190b74969ae455872e22b081eb71864dd6ce179556929ab51251f1f2a3a60191e17c2887ae86e185543122365cdcd5dc61d0347d49212cc710c4; ll=7fd06e815b796be3df069dec7836c3df; ua=%E7%82%AC%E7%81%8F; ctu=51082c643abca2e4a4729d35da419781a5baa93bd770d869eb48bf863a23f42c; _lxsdk_s=1714a6f6dc7-af0-f8f-b5a%7C%7C232'}
i = 1
for n in range(1,10):
    url = url_b+str(n)

    req=urllib.request.Request(url,headers=headers)
    
    response = urllib.request.urlopen(req)
    html=response.read().decode('utf-8')
    
 
    soup = BeautifulSoup(html,'html.parser')
    all_item_divs = soup.find_all(class_='txt')
    #print(all_item_divs )
    if all_item_divs:
        for item in all_item_divs:
            all_topics = item.find_all('a')
       
            for topic in all_topics:
                click = topic['data-click-name']
                title=''
                href=''
                phone =''
                like =''
                price ='' 
                if click == "shop_title_click":
                    title = topic['title']
                    href = topic['href'].strip()
                    #print('{0} {1}'.format(title,href))
                    #headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.1; rv:67.0) Gecko/20100101 Firefox/67.0'}
                    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36',
         'cookie': 's_ViewType=10; _lxsdk_cuid=1714a6f6dc576-0351aabd617323-5463377a-a41c3-1714a6f6dc6c8; _lxsdk=1714a6f6dc576-0351aabd617323-5463377a-a41c3-1714a6f6dc6c8; _hc.v=9b3f5fce-2b77-d20f-1b3b-ebf7c793f66e.1586091755; wed_user_path=2786|0; aburl=1; cy=17; cye=xian; dplet=4a206248cf9cd97ea5b23332ab9c74c6; dper=017c7cde4689ccbe3b4e92a96c6e578e4d48e3d871c987831fb9f5436f0c11b16b545df35a4c190b74969ae455872e22b081eb71864dd6ce179556929ab51251f1f2a3a60191e17c2887ae86e185543122365cdcd5dc61d0347d49212cc710c4; ll=7fd06e815b796be3df069dec7836c3df; ua=%E7%82%AC%E7%81%8F; ctu=51082c643abca2e4a4729d35da419781a5baa93bd770d869eb48bf863a23f42c; _lxsdk_s=1714a6f6dc7-af0-f8f-b5a%7C%7C232'}

                    req_shop=urllib.request.Request(href,headers=headers)
                    resp_shop = urllib.request.urlopen(req_shop)
                    html_shop=resp_shop.read().decode('utf-8')
                    soup_shop = BeautifulSoup(html_shop ,'html.parser')
                    like_price = soup_shop.find_all(class_='rst-taste')
                    shop_info = soup_shop.find_all(class_='shopinfor')     
                    #print(shop_info)                         
                    if shop_info:
                        phone = shop_info[0].find_all('p')[0].get_text()
                        #print(phone)
                        if like_price:
                            like = like_price[0].find_all('a')[0].get_text()
                            #print(like)
                            price = like_price[0].find_all('strong')[0].get_text()
                            #print(price)
                    else:                                         
                        like_price = soup_shop.find_all(class_='comment-rst')
                        shop_infos = soup_shop.find_all(class_='shop-info-content')
                        if like_price:
                            if like_price[0].find('a'):
                                like = like_price[0].find('a').get_text()
                            #print(like)
                            if like_price[0].find('dd'):
                                price = like_price[0].find('dd').get_text()
                            #print(price)
                        for shop_info in shop_infos:
                            #print(shop_info)
                            for x in shop_info.find_all('a'):
                                #print(x)
                                if x.has_attr('data-real'):
                                    phone = x['data-real']
                                    #print(phone)
                    print('{0}\t{1}\t{2}\t{3}\t{4}\t'.format(title,href,like,price,phone))
                    sheet.write(i,0,title)
                    sheet.write(i,1,href)
                    sheet.write(i,2,like)
                    sheet.write(i,3,price)
                    sheet.write(i,4,phone)
                    
                    i = i + 1
xls.save('dianping.xls')
print('running over')
# Out:
# 好孕妈妈月嫂育儿嫂(旺座国际总店)	http://www.dianping.com/shop/127148438	339封点评	￥10598	商家客服：4001764171
#
# 金贝儿月嫂(大差市店)	http://www.dianping.com/shop/1252546534
# 133封点评
#             	¥10632	18502988629
# MIND 普拉提	http://www.dianping.com/shop/1353281886
# 安心妈妈月子中心(北郊店)	http://www.dianping.com/shop/75253324
# 499封点评
#             	¥28432	4000055810
# 曲江妇产医院	http://www.dianping.com/shop/4674300
# 悦长安母婴专护中心(凤城八路店)	http://www.dianping.com/shop/103004999	216封点评	￥26238	商家客服：029-86683868  17392835963
#
# 芒果妈咪月嫂服务中心(未央总店)	http://www.dianping.com/shop/120003421	106封点评	￥9484	商家客服：4001760442
#
# 金贝儿月嫂(交大店)	http://www.dianping.com/shop/132802110
# 99封点评
#             	¥11067	18502988627
# 吉一生小儿推拿·催乳(江林新城店)	http://www.dianping.com/shop/113515225
# 10封点评
#             	-	18066530736
# 一悦一生(半坡店)	http://www.dianping.com/shop/130059150	23封点评	￥26378	商家客服：029-83511808
#
# 西安女子医院	http://www.dianping.com/shop/111538430
# 完美月子会所(北郊店)	http://www.dianping.com/shop/76364376	67封点评	￥18332	商家客服：4001764805
# 悦享时光母婴护理中心(曲江尊享店)	http://www.dianping.com/shop/94264103
# 31封点评
#             	¥24496	13227867617
# 优美妈妈母婴服务店	http://www.dianping.com/shop/1932934868	2封点评	-	商家客服：18629083731
#
# 一悦一生母婴体验园	http://www.dianping.com/shop/90969110
# 131封点评
#             	¥45826	029--86185566
# 禧贝阁母婴呵护中心(大雁塔店)	http://www.dianping.com/shop/1942765459	11封点评	￥30483	商家客服：4001857487
#
# 珍如坊·产后恢复中心	http://www.dianping.com/shop/90302134	40封点评	￥234	商家客服：4000303096-02836
#
# 菩提果月嫂(高新店)	http://www.dianping.com/shop/1828851862
# 2封点评
#             	-	15829089318
# 昕诺月嫂家政公司	http://www.dianping.com/shop/94429809
# 6封点评
#             	¥8766	18161911145
# 好妈妈	http://www.dianping.com/shop/131193860
# 3封点评
#             	-	15829251786
# 爱月儿国际母婴护理中心	http://www.dianping.com/shop/129774597
# 16封点评
#             	¥17342	15502980836
# 嗨妈咪私享月子会所	http://www.dianping.com/shop/20734820
# 95封点评
#             	¥20382	029--68756300
# 橦心堂母婴健康管理中心(高新店)	http://www.dianping.com/shop/110699470
# 67封点评
#             	¥3028	029--88225995
# 孕美康产后恢复中心	http://www.dianping.com/shop/1028847351	8封点评	-	商家客服：13519136435
#
# 北京好韵妈妈月嫂中心(西安雁塔店)	http://www.dianping.com/shop/130604393
# 6封点评
#             	-	18292064216
# 女王臻爱月子会所	http://www.dianping.com/shop/130675788	9封点评	￥30688	商家客服：029-68569888  18821702917
#
# 妈咪管家家政服务(曲江店)	http://www.dianping.com/shop/1139017167
# 爱尚月嫂到家服务中心	http://www.dianping.com/shop/689695138	2封点评	-	商家客服：4000303096-95176
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-b1c6ddbcf61f> in <module>()
#      62                             like = like_price[0].find_all('a')[0].get_text()
#      63                             #print(like)
# ---> 64                             price = like_price[0].find_all('strong')[0].get_text()
#      65                             #print(price)
#      66                     else:
#
# IndexError: list index out of range

# %%
import urllib
from bs4 import BeautifulSoup
import xlwt
import json
import re

xls = xlwt.Workbook()
sheet = xls.add_sheet('ctx')
sheet.write(0,0,'title')
sheet.write(0,1,'url')
sheet.write(0,2,'like')
sheet.write(0,3,'price')
sheet.write(0,4,'phone')

url_b = "http://www.dianping.com/search/keyword/17/0_%E6%9C%88%E5%AD%90%E4%BC%9A%E6%89%80/o3p"
headers={'Accept': 'application/json, text/javascript', 
         'User-Agent':'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36',
         'cookie': 's_ViewType=10; _lxsdk_cuid=1714a6f6dc576-0351aabd617323-5463377a-a41c3-1714a6f6dc6c8; _lxsdk=1714a6f6dc576-0351aabd617323-5463377a-a41c3-1714a6f6dc6c8; _hc.v=9b3f5fce-2b77-d20f-1b3b-ebf7c793f66e.1586091755; wed_user_path=2786|0; aburl=1; cy=17; cye=xian; dplet=4a206248cf9cd97ea5b23332ab9c74c6; dper=017c7cde4689ccbe3b4e92a96c6e578e4d48e3d871c987831fb9f5436f0c11b16b545df35a4c190b74969ae455872e22b081eb71864dd6ce179556929ab51251f1f2a3a60191e17c2887ae86e185543122365cdcd5dc61d0347d49212cc710c4; ll=7fd06e815b796be3df069dec7836c3df; ua=%E7%82%AC%E7%81%8F; ctu=51082c643abca2e4a4729d35da419781a5baa93bd770d869eb48bf863a23f42c; _lxsdk_s=1714a6f6dc7-af0-f8f-b5a%7C%7C232'}
i = 1
for n in range(1,10):
    url = url_b+str(n)

    req=urllib.request.Request(url,headers=headers)
    
    response = urllib.request.urlopen(req)
    html=response.read().decode('utf-8')
    
 
    soup = BeautifulSoup(html,'html.parser')
    all_item_divs = soup.find_all(class_='txt')
    #print(all_item_divs )
    if all_item_divs:
        for item in all_item_divs:
            all_topics = item.find_all('a')
       
            for topic in all_topics:
                click = topic['data-click-name']
                title=''
                href=''
                phone =''
                like =''
                price ='' 
                if click == "shop_title_click":
                    title = topic['title']
                    href = topic['href'].strip()
                    #print('{0} {1}'.format(title,href))
                    #headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.1; rv:67.0) Gecko/20100101 Firefox/67.0'}
                    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36',
         'cookie': 's_ViewType=10; _lxsdk_cuid=1714a6f6dc576-0351aabd617323-5463377a-a41c3-1714a6f6dc6c8; _lxsdk=1714a6f6dc576-0351aabd617323-5463377a-a41c3-1714a6f6dc6c8; _hc.v=9b3f5fce-2b77-d20f-1b3b-ebf7c793f66e.1586091755; wed_user_path=2786|0; aburl=1; cy=17; cye=xian; dplet=4a206248cf9cd97ea5b23332ab9c74c6; dper=017c7cde4689ccbe3b4e92a96c6e578e4d48e3d871c987831fb9f5436f0c11b16b545df35a4c190b74969ae455872e22b081eb71864dd6ce179556929ab51251f1f2a3a60191e17c2887ae86e185543122365cdcd5dc61d0347d49212cc710c4; ll=7fd06e815b796be3df069dec7836c3df; ua=%E7%82%AC%E7%81%8F; ctu=51082c643abca2e4a4729d35da419781a5baa93bd770d869eb48bf863a23f42c; _lxsdk_s=1714a6f6dc7-af0-f8f-b5a%7C%7C232'}

                    req_shop=urllib.request.Request(href,headers=headers)
                    resp_shop = urllib.request.urlopen(req_shop)
                    html_shop=resp_shop.read().decode('utf-8')
                    soup_shop = BeautifulSoup(html_shop ,'html.parser')
                    like_price = soup_shop.find_all(class_='rst-taste')
                    shop_info = soup_shop.find_all(class_='shopinfor')     
                    #print(shop_info)                         
                    if shop_info:
                        phone = shop_info[0].find_all('p')[0].get_text()
                        #print(phone)
                        if like_price:
                            if like_price[0].find_all('a'):
                                like = like_price[0].find_all('a')[0].get_text()
                                #print(like)
                            if like_price[0].find_all('strong'):
                                price = like_price[0].find_all('strong')[0].get_text()
                                #print(price)
                    else:                                         
                        like_price = soup_shop.find_all(class_='comment-rst')
                        shop_infos = soup_shop.find_all(class_='shop-info-content')
                        if like_price:
                            if like_price[0].find('a'):
                                like = like_price[0].find('a').get_text()
                            #print(like)
                            if like_price[0].find('dd'):
                                price = like_price[0].find('dd').get_text()
                            #print(price)
                        for shop_info in shop_infos:
                            #print(shop_info)
                            for x in shop_info.find_all('a'):
                                #print(x)
                                if x.has_attr('data-real'):
                                    phone = x['data-real']
                                    #print(phone)
                    print('{0}\t{1}\t{2}\t{3}\t{4}\t'.format(title,href,like,price,phone))
                    sheet.write(i,0,title)
                    sheet.write(i,1,href)
                    sheet.write(i,2,like)
                    sheet.write(i,3,price)
                    sheet.write(i,4,phone)
                    
                    i = i + 1
xls.save('dianping.xls')
print('running over')
# Out:
# 好孕妈妈月嫂育儿嫂(旺座国际总店)	http://www.dianping.com/shop/127148438	339封点评	￥10598	商家客服：4001764171
#
# 金贝儿月嫂(大差市店)	http://www.dianping.com/shop/1252546534
# 133封点评
#             	¥10632	18502988629
# MIND 普拉提	http://www.dianping.com/shop/1353281886
# 安心妈妈月子中心(北郊店)	http://www.dianping.com/shop/75253324
# 499封点评
#             	¥28432	4000055810
# 曲江妇产医院	http://www.dianping.com/shop/4674300
# 悦长安母婴专护中心(凤城八路店)	http://www.dianping.com/shop/103004999	216封点评	￥26238	商家客服：029-86683868  17392835963
#
# 芒果妈咪月嫂服务中心(未央总店)	http://www.dianping.com/shop/120003421	106封点评	￥9484	商家客服：4001760442
#
# 金贝儿月嫂(交大店)	http://www.dianping.com/shop/132802110
# 99封点评
#             	¥11067	18502988627
# 爱菲月子会所(长安店)	http://www.dianping.com/shop/128027816	156封点评	￥19691	商家客服：13991954900  029-85950575
#
# 胜蓝月子会所(立丰国际店)	http://www.dianping.com/shop/23294982
# 371封点评
#             	¥22449	029--82284440
# 金贝儿月嫂(高新店)	http://www.dianping.com/shop/131450104
# 93封点评
#             	¥10540	029--89106537
# 品悦宫月子中心	http://www.dianping.com/shop/76717479	313封点评	￥23550	商家客服：4001769335
#
# 爱菲月子中心(太白店)	http://www.dianping.com/shop/67069768
# 440封点评
#             	¥21220	029--62890055
# 昕悦里母婴精致护理中心	http://www.dianping.com/shop/122270210
# 177封点评
#             	¥23021	18792701756
# 禧贝阁母婴呵护中心(市图书馆店)	http://www.dianping.com/shop/126243413	119封点评	￥29058	商家客服：4000303096-97270
#
# 爱菲月子中心(北郊店)	http://www.dianping.com/shop/72376983	189封点评	￥18908	商家客服：4000303096-05779
#
# 安心妈妈月子中心(高新店)	http://www.dianping.com/shop/4281637
# 333封点评
#             	¥27512	029--84317990
# 阳光贝儿母婴月子会所	http://www.dianping.com/shop/10008947	188封点评	￥20312	商家客服：4001103664
#
# 爱知儿母婴护理中心	http://www.dianping.com/shop/93190451
# 125封点评
#             	¥23005	13060423939
# 金月汇月子会所(经开店)	http://www.dianping.com/shop/98375700
# 193封点评
#             	¥24901	029--89609966
# 贝美月子会所(半坡店)	http://www.dianping.com/shop/69043117	239封点评	￥21506	商家客服：4001763642
#
# 金沛产后恢复中心(经开店)	http://www.dianping.com/shop/93397891	165封点评	￥4306	商家客服：029-89821838  18189151426
#
# 纵享怡月母婴月子会所(东郊店)	http://www.dianping.com/shop/77486084	171封点评	￥20004	商家客服：4000303096-91019
